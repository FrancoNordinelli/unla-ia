# %%
# %run main.py
# Out:
# Max leaf nodes: 5 	 Mean Absolute Error: 385696.54278937966
# Max leaf nodes: 10 	 Mean Absolute Error: 333908.4783704852
# Max leaf nodes: 20 	 Mean Absolute Error: 311113.0621330481
# Max leaf nodes: 30 	 Mean Absolute Error: 297673.44261564675
#
# Mejor modelo con max_leaf_nodes = 30 tiene un MAE de 297673.44261564675
